# %%
import pandas as pd
import numpy as np
import re
import time

import requests as rq
import bs4 as bs4 # beautifulsoup4
import json

# %%
queries = ["machine+learning", "data+science", "kaggle"]
url = "https://www.youtube.com/results?search_query={query}&sp=CAI%253D&p={page}"

# %% [markdown]
# # Coleta dos dados

# %%
for query in queries:
    for page in range(1,101):
        urll = url.format(query=query, page=page)
        print(urll)
        response = rq.get(urll)
        
        with open("./dados_brutos/{}_{}.html".format(query, page), 'w+') as output:
            output.write(response.text)
        time.sleep(2)
# Out:
# https://www.youtube.com/results?search_query=machine+learning&sp=CAI%253D&p=1

# %% [markdown]
# # Processamento dos dados brutos

# %%
for query in queries:
    for page in range(1,2):
        with open("./dados_brutos/{}_{}.html".format(query, page), 'r+') as inp:
            page_html = inp.read()
            
            parsed = bs4.BeautifulSoup(page_html)
            
            tags = parsed.findAll("a")
        
            for e in tags:
                if e.has_attr("aria-describedby"):
                    link = e['href']
                    title = e['title']
                    with open("parsed_videos.json", 'a+') as output:
                        data = {"link": link, "title": title, "query": query}
                        output.write("{}\n".format(json.dumps(data)))

# %% [markdown]
# # Verificação do resultado

# %%
df = pd.read_json("parsed_videos.json", lines=True)

# %%
df.sort_values("title")
# Out:
#                     link                                              title  \
# 17  /watch?v=MuR2eS2QPMI                  Causal Models in Machine Learning
# 36  /watch?v=MuR2eS2QPMI                  Causal Models in Machine Learning
# 34  /watch?v=oh_RzrJULIc  DataScience machine learning, deep learning cl...
# 15  /watch?v=oh_RzrJULIc  DataScience machine learning, deep learning cl...
# 29  /watch?v=s37Kc2bm-JY  G. Sanguinetti - Probabilistic machine learnin...
# 10  /watch?v=s37Kc2bm-JY  G. Sanguinetti - Probabilistic machine learnin...
# 7   /watch?v=7E9NuFbYarg  Is there a real-world role of Artificial Intel...
# 26  /watch?v=7E9NuFbYarg  Is there a real-world role of Artificial Intel...
# 28  /watch?v=kODjxmjNzVU  Leveraging BERT + Deep Learning for Impactful ...
# 9   /watch?v=kODjxmjNzVU  Leveraging BERT + Deep Learning for Impactful ...
# 1   /watch?v=dSnDjfz-i8s  MACHINE LEARNING GENERATED MUSIC - Introductio...
# 20  /watch?v=dSnDjfz-i8s  MACHINE LEARNING GENERATED MUSIC - Introductio...
# 33  /watch?v=UKTQ90SHqzs                           Machine Learning Program
# 14  /watch?v=UKTQ90SHqzs                           Machine Learning Program
# 8   /watch?v=fh8KQlwTmfs  Machine Learning application to create experim...
# 27  /watch?v=fh8KQlwTmfs  Machine Learning application to create experim...
# 19  /watch?v=X3K8B5SrwxI  Machine Learning com Javascript utilizando Ten...
# 0   /watch?v=X3K8B5SrwxI  Machine Learning com Javascript utilizando Ten...
# 18  /watch?v=iU0kk2SPdak  Machine Learning with Amazon Web Services Sage...
# 37  /watch?v=iU0kk2SPdak  Machine Learning with Amazon Web Services Sage...
# 22  /watch?v=l4Yzaxz50Sw  Machine Learning with Python | Machine Learnin...
# 3   /watch?v=l4Yzaxz50Sw  Machine Learning with Python | Machine Learnin...
# 11  /watch?v=9RtOGUn7zns                          O que é Machine Learning?
# 30  /watch?v=9RtOGUn7zns                          O que é Machine Learning?
# 23  /watch?v=WYfKtkqPpBA  PYTHON SOURCE CODE FOR TWITTER SENTIMENTAL ANA...
# 4   /watch?v=WYfKtkqPpBA  PYTHON SOURCE CODE FOR TWITTER SENTIMENTAL ANA...
# 21  /watch?v=W3hpbscsaMw  Playing Flappy Bird - Machine Learning [A.I Le...
# 2   /watch?v=W3hpbscsaMw  Playing Flappy Bird - Machine Learning [A.I Le...
# 35  /watch?v=c5ZjDMLH9iM  Reconocimiento facial con Javascript a través ...
# 16  /watch?v=c5ZjDMLH9iM  Reconocimiento facial con Javascript a través ...
# 25  /watch?v=ljZgcbu7onY  Smart Job Order Prioritization with AI By Shiv...
# 6   /watch?v=ljZgcbu7onY  Smart Job Order Prioritization with AI By Shiv...
# 13  /watch?v=eV4IWmpZWX8  Timnit Gebru - Strategies for Collecting Socio...
# 32  /watch?v=eV4IWmpZWX8  Timnit Gebru - Strategies for Collecting Socio...
# 24  /watch?v=WR3DojilTaM  What is Continuous Intelligence in Machine Lea...
# 5   /watch?v=WR3DojilTaM  What is Continuous Intelligence in Machine Lea...
# 31  /watch?v=hK9Gbmd3pC4  ¿POR QUÉ MI MODELO DE MACHINE LEARNING NO FUNC...
# 12  /watch?v=hK9Gbmd3pC4  ¿POR QUÉ MI MODELO DE MACHINE LEARNING NO FUNC...
#
#                query
# 17  machine+learning
# 36  machine+learning
# 34  machine+learning
# 15  machine+learning
# 29  machine+learning
# 10  machine+learning
# 7   machine+learning
# 26  machine+learning
# 28  machine+learning
# 9   machine+learning
# 1   machine+learning
# 20  machine+learning
# 33  machine+learning
# 14  machine+learning
# 8   machine+learning
# 27  machine+learning
# 19  machine+learning
# 0   machine+learning
# 18  machine+learning
# 37  machine+learning
# 22  machine+learning
# 3   machine+learning
# 11  machine+learning
# 30  machine+learning
# 23  machine+learning
# 4   machine+learning
# 21  machine+learning
# 2   machine+learning
# 35  machine+learning
# 16  machine+learning
# 25  machine+learning
# 6   machine+learning
# 13  machine+learning
# 32  machine+learning
# 24  machine+learning
# 5   machine+learning
# 31  machine+learning
# 12  machine+learning
